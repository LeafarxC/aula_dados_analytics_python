# %% [markdown]
# <a href="https://colab.research.google.com/github/LeafarxC/aula_dados_analytics_python/blob/main/read_save_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#ler de arquivos csv

url = ''

df = pd.read_csv(url) #pd.read_csv()

# %%
print(df)

# %%
#ler aquivos xlsx
df2 = pd.read_excel('exemplo.xlsx')
print(df2)

# %%
#Salvar no formato csv
df3 = pd.DataFrames({
    'Fruta' : ['Maçã', 'Banana', 'Laranja'],
    'Quantidade' : [100, 150, 120]
})

df3.to_csv('frutas.csv', index=False)

# %%
df4 = pd.read_csv('frutas.csv')

# %%
print(df4)

# %%
#salvar arquivos xlsx
df5 = pd.DataFrame({
    'País' : ['Brasil', 'Argentina', 'Portugal'],
    'Quantidade' : [100, 150, 120]
})
print(df5)

# %%
df5.to_excel('paises.xlsx', index=False)

# %%
df6 = pd.read_excel('paises.xlsx')
print(df6)
